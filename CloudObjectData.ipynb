# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
data=("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")
df= pd.read_csv(data)

# %%
df.head(20)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            4                     I am a developer by profession       No
# 1            9                     I am a developer by profession      Yes
# 2           13                     I am a developer by profession      Yes
# 3           16                     I am a developer by profession      Yes
# 4           17                     I am a developer by profession      Yes
# 5           19                     I am a developer by profession      Yes
# 6           20  I am not primarily a developer, but I write co...       No
# 7           22                     I am a developer by profession      Yes
# 8           23                     I am a developer by profession      Yes
# 9           24                     I am a developer by profession      Yes
# 10          25                     I am a developer by profession       No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11398 non-null  int64
#  1   MainBranch              11398 non-null  object
#  2   Hobbyist                11398 non-null  object
#  3   OpenSourcer             11398 non-null  object
#  4   OpenSource              11317 non-null  object
#  5   Employment              11398 non-null  object
#  6   Country                 11398 non-null  object
#  7   Student                 11347 non-null  object
#  8   EdLevel                 11286 non-null  object
#  9   UndergradMajor          10661 non-null  object
#  10  EduOther                11234 non-null  object
#  11  OrgSize                 11302 non-null  object
#  12  DevType                 11333 non-null  object
#  13  YearsCode               11389 non-null  object
# ...

# %%
df.describe(include= "all")
# Out:
#           Respondent                      MainBranch Hobbyist OpenSourcer  \
# count   11398.000000                           11398    11398       11398
# unique           NaN                               2        2           4
# top              NaN  I am a developer by profession      Yes       Never
# freq             NaN                           10618     9273        3652
# mean    12490.392437                             NaN      NaN         NaN
# std      7235.461999                             NaN      NaN         NaN
# min         4.000000                             NaN      NaN         NaN
# 25%      6264.250000                             NaN      NaN         NaN
# 50%     12484.000000                             NaN      NaN         NaN
# 75%     18784.750000                             NaN      NaN         NaN
# max     25142.000000                             NaN      NaN         NaN
#
#                                                OpenSource          Employment  \
# ...

# %%
sns.boxplot(x= "CompTotal", y= "Respondent", data= df)
# Out:
# <AxesSubplot:xlabel='CompTotal', ylabel='Respondent'>

# %%
df['CompTotal'].unique()
# Out:
# array([ 61000., 138000.,  90000., ...,  22730., 552000.,  74400.])

# %%
df.corr()
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.013490       0.002181    -0.015314    0.004621
# CompTotal       -0.013490   1.000000       0.001037     0.003510    0.007063
# ConvertedComp    0.002181   0.001037       1.000000     0.021143   -0.033865
# WorkWeekHrs     -0.015314   0.003510       0.021143     1.000000    0.026517
# CodeRevHrs       0.004621   0.007063      -0.033865     0.026517    1.000000
# Age              0.004041   0.006970       0.105386     0.036518   -0.020469
#
#                     Age
# Respondent     0.004041
# CompTotal      0.006970
# ConvertedComp  0.105386
# WorkWeekHrs    0.036518
# CodeRevHrs    -0.020469
# Age            1.000000

# %%
df[['CompTotal', 'ConvertedComp', 'Age']].corr()
# Out:
#                CompTotal  ConvertedComp       Age
# CompTotal       1.000000       0.001037  0.006970
# ConvertedComp   0.001037       1.000000  0.105386
# Age             0.006970       0.105386  1.000000

# %%
sns.residplot(df['CompTotal'], df['Age'])
# Out:
# <AxesSubplot:xlabel='CompTotal', ylabel='Age'>

# %%
df.dropna(subset= ['CompTotal'], axis= 0, inplace=True)

# %%
mean= df['Respondent'].mean()
print(mean)
# Out:
# 12485.668198285764

# %%
df['CompTotal'].replace(np.nan, 12)
# Out:
# 0         61000.0
# 1        138000.0
# 2         90000.0
# 3         29000.0
# 4         90000.0
#            ...
# 11392       800.0
# 11393    130000.0
# 11394     74400.0
# 11395    105000.0
# 11396     80000.0
# Name: CompTotal, Length: 10514, dtype: float64

# %%
lm= LinearRegression()

# %%
x= df[['CompTotal']]
y= df['Respondent']
lm.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
df['CompTotal']= df['CompTotal'].astype('int')

# %%
df['CompTotal']
# Out:
# 0         61000
# 1        138000
# 2         90000
# 3         29000
# 4         90000
#           ...
# 11392       800
# 11393    130000
# 11394     74400
# 11395    105000
# 11396     80000
# Name: CompTotal, Length: 10514, dtype: int64

# %%
yhat= lm.predict(x)
print(yhat)
# Out:
# [12500.42464656 12499.65852783 12500.13610833 ... 12500.291322
#  12499.98686443 12500.23560427]

# %%
lm.intercept_
# Out:
# 12501.031571786632

# %%
lm.score(x, y)
# Out:
# 0.00017943360756300653

# %%
lm.coef_
# Out:
# array([-9.94959391e-06])

# %%
Respondent= 12501.03 -9.95 
print(Respondent)
# Out:
# 12491.08

# %%
sns.residplot(df['Respondent'], df['CompTotal'])
# Out:
# <AxesSubplot:xlabel='Respondent', ylabel='CompTotal'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_341/1891786488.py in <module>
# ----> 1 f= np.polyfit(x,y,3)
#       2 p= np.polyid(f)
#       3 print(p)
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~/conda/envs/python/lib/python3.7/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     626         raise ValueError("expected deg >= 0")
#     627     if x.ndim != 1:
# --> 628         raise TypeError("expected 1D vector for x")
#     629     if x.size == 0:
#     630         raise TypeError("expected non-empty vector for x")
#
# TypeError: expected 1D vector for x
